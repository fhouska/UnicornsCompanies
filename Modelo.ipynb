# %% [markdown]
# # MACHINE LEARNIG

# %% [markdown]
# Realizamos un **modelo predictivo** de **regresión lineal** para predecir el valor de la inversión en función de las
#
# siguientes variables: Inversión, País, Continente, Industria, Año en que se fundó la empresa, el porcentaje de rentabilidad que se quiere sobre la inversión.
#
# En la implementación de este modelo, utilizamos la biblioteca **pycaret**.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
import category_encoders as ce
from sklearn.ensemble import GradientBoostingRegressor

# %%
df = pd.read_csv("Data/df_reg.csv")

# %%
df.head()
# Out:
#                           Industry        Country  Year_Founded  Funding  \
# 0          Artificial intelligence          China          2012     8000
# 1                            Other  United States          2002     7000
# 2  E-commerce & direct-to-consumer          China          2008     2000
# 3                          Fintech  United States          2010     2000
# 4                          Fintech         Sweden          2005     4000
#
#        Continent  Valuation
# 0           Asia     180000
# 1  North America     100000
# 2           Asia     100000
# 3  North America      95000
# 4         Europe      46000

# %%
#años desde que se fundó
df['Years_Since_Founded'] = pd.Timestamp.now().year - df['Year_Founded']

# ratio de financiación y la edad de la empresa
df['Funding_Age_Ratio'] = df['Funding'] / df['Years_Since_Founded']

# Rentabilidad sobre la inversión
df['ROI'] = df['Valuation'] - df['Funding']

# %%
df.head()
# Out:
#                           Industry        Country  Year_Founded  Funding  \
# 0          Artificial intelligence          China          2012     8000
# 1                            Other  United States          2002     7000
# 2  E-commerce & direct-to-consumer          China          2008     2000
# 3                          Fintech  United States          2010     2000
# 4                          Fintech         Sweden          2005     4000
#
#        Continent  Valuation  Years_Since_Founded  Funding_Age_Ratio     ROI
# 0           Asia     180000                   11         727.272727  172000
# 1  North America     100000                   21         333.333333   93000
# 2           Asia     100000                   15         133.333333   98000
# 3  North America      95000                   13         153.846154   93000
# 4         Europe      46000                   18         222.222222   42000

# %%
df.columns
# Out:
# Index(['Industry', 'Country', 'Year_Founded', 'Funding', 'Continent',
#        'Valuation', 'Years_Since_Founded', 'Industry_Country',
#        'Funding_Age_Ratio', 'Industry_Funding', 'ROI'],
#       dtype='object')

# %%
df= df[['Industry', 'Country', 'Year_Founded', 'Funding', 'Continent', 'Years_Since_Founded', 'Industry_Country',
       'Funding_Age_Ratio', 'Industry_Funding', 'ROI','Valuation']]

# %% [markdown]
# Como tus datos de muestra no son suficientes para un modelo, he decidido crear nuevos a traves de muestras añadiéndole ruido.

# %%
num_rows_to_generate = 900

min_values = df.min()
max_values = df.max()

new_rows = df.sample(n=num_rows_to_generate, replace=True)

for column in df.select_dtypes(include=[np.number]).columns:
    noise = np.random.normal(0, 1, new_rows[column].shape)
    new_rows[column] += noise
    new_rows[column] = np.clip(new_rows[column], min_values[column], max_values[column])

new_rows['Valuation'] = np.clip(new_rows['Valuation'], None, df['Valuation'].max())

df = pd.concat([df, new_rows], ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1945 entries, 0 to 1944
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Industry             1945 non-null   object
#  1   Country              1945 non-null   object
#  2   Year_Founded         1945 non-null   float64
#  3   Funding              1945 non-null   float64
#  4   Continent            1945 non-null   object
#  5   Years_Since_Founded  1945 non-null   float64
#  6   Industry_Country     1945 non-null   object
#  7   Funding_Age_Ratio    1945 non-null   float64
#  8   Industry_Funding     1945 non-null   object
#  9   ROI                  1945 non-null   float64
#  10  Valuation            1945 non-null   float64
# dtypes: float64(6), object(5)
# memory usage: 167.3+ KB

# %% [markdown]
# # Modelización

# %%
#importamos pycaret regression para calcular el price
from pycaret.regression import *

# %%
#hacemos un setup con visa a nuestro target ROI
setup = setup(df, target = 'Valuation',remove_outliers = True)
# Out:
# <style type="text/css">
# #T_0183f_row9_col1, #T_0183f_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0183f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0183f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0183f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0183f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0183f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0183f_row0_col1" class="data row0 col1" >4195</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0183f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0183f_row1_col1" class="data row1 col1" >Valuation</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0183f_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_0183f_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0183f_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_0183f_row3_col1" class="data row3 col1" >(1945, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0183f_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_0183f_row4_col1" class="data row4 col1" >(1877, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0183f_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_0183f_row5_col1" class="data row5 col1" >(1293, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0183f_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_0183f_row6_col1" class="data row6 col1" >(584, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0183f_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_0183f_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0183f_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_0183f_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0183f_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_0183f_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0183f_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_0183f_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0183f_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_0183f_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0183f_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_0183f_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0183f_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_0183f_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0183f_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_0183f_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0183f_row15_col0" class="data row15 col0" >Remove outliers</td>
#       <td id="T_0183f_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0183f_row16_col0" class="data row16 col0" >Outliers threshold</td>
#       <td id="T_0183f_row16_col1" class="data row16 col1" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0183f_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_0183f_row17_col1" class="data row17 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0183f_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_0183f_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0183f_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_0183f_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_0183f_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_0183f_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_0183f_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_0183f_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_0183f_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_0183f_row22_col1" class="data row22 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_0183f_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_0183f_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_0183f_row23_col1" class="data row23 col1" >0f24</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Evaluamos modelos
best = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           00:26:15
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
# <style type="text/css">
# #T_760fd th {
#   text-align: left;
# }
# #T_760fd_row0_col0, #T_760fd_row0_col1, #T_760fd_row0_col2, #T_760fd_row0_col3, #T_760fd_row1_col0, #T_760fd_row1_col1, #T_760fd_row1_col2, #T_760fd_row1_col3, #T_760fd_row2_col0, #T_760fd_row2_col1, #T_760fd_row2_col2, #T_760fd_row2_col3, #T_760fd_row3_col0, #T_760fd_row3_col1, #T_760fd_row3_col2, #T_760fd_row3_col3, #T_760fd_row3_col5, #T_760fd_row3_col6, #T_760fd_row4_col0, #T_760fd_row4_col1, #T_760fd_row5_col0, #T_760fd_row5_col2, #T_760fd_row5_col3, #T_760fd_row6_col0, #T_760fd_row6_col1, #T_760fd_row6_col2, #T_760fd_row6_col3, #T_760fd_row7_col0, #T_760fd_row7_col1, #T_760fd_row7_col2, #T_760fd_row7_col3, #T_760fd_row8_col0, #T_760fd_row8_col1, #T_760fd_row8_col2, #T_760fd_row8_col3, #T_760fd_row9_col0, #T_760fd_row9_col1, #T_760fd_row9_col2, #T_760fd_row9_col3, #T_760fd_row9_col4, #T_760fd_row9_col5, #T_760fd_row9_col6, #T_760fd_row10_col0, #T_760fd_row10_col1, #T_760fd_row10_col2, #T_760fd_row10_col3, #T_760fd_row10_col4, #T_760fd_row10_col5, #T_760fd_row10_col6, #T_760fd_row11_col0, #T_760fd_row11_col1, #T_760fd_row11_col2, #T_760fd_row11_col3, #T_760fd_row11_col4, #T_760fd_row11_col5, #T_760fd_row11_col6, #T_760fd_row12_col0, #T_760fd_row12_col1, #T_760fd_row12_col2, #T_760fd_row12_col3, #T_760fd_row12_col4, #T_760fd_row12_col5, #T_760fd_row12_col6, #T_760fd_row13_col0, #T_760fd_row13_col1, #T_760fd_row13_col2, #T_760fd_row13_col3, #T_760fd_row13_col4, #T_760fd_row13_col5, #T_760fd_row13_col6, #T_760fd_row14_col0, #T_760fd_row14_col1, #T_760fd_row14_col2, #T_760fd_row14_col3, #T_760fd_row14_col4, #T_760fd_row14_col5, #T_760fd_row14_col6, #T_760fd_row15_col0, #T_760fd_row15_col1, #T_760fd_row15_col2, #T_760fd_row15_col3, #T_760fd_row15_col4, #T_760fd_row15_col5, #T_760fd_row15_col6, #T_760fd_row16_col0, #T_760fd_row16_col1, #T_760fd_row16_col2, #T_760fd_row16_col3, #T_760fd_row16_col4, #T_760fd_row16_col5, #T_760fd_row16_col6, #T_760fd_row17_col0, #T_760fd_row17_col1, #T_760fd_row17_col2, #T_760fd_row17_col3, #T_760fd_row17_col4, #T_760fd_row17_col5, #T_760fd_row17_col6 {
#   text-align: left;
# }
# #T_760fd_row0_col4, #T_760fd_row0_col5, #T_760fd_row0_col6, #T_760fd_row1_col4, #T_760fd_row1_col5, #T_760fd_row1_col6, #T_760fd_row2_col4, #T_760fd_row2_col5, #T_760fd_row2_col6, #T_760fd_row3_col4, #T_760fd_row4_col2, #T_760fd_row4_col3, #T_760fd_row4_col4, #T_760fd_row4_col5, #T_760fd_row4_col6, #T_760fd_row5_col1, #T_760fd_row5_col4, #T_760fd_row5_col5, #T_760fd_row5_col6, #T_760fd_row6_col4, #T_760fd_row6_col5, #T_760fd_row6_col6, #T_760fd_row7_col4, #T_760fd_row7_col5, #T_760fd_row7_col6, #T_760fd_row8_col4, #T_760fd_row8_col5, #T_760fd_row8_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_760fd_row0_col7, #T_760fd_row1_col7, #T_760fd_row3_col7, #T_760fd_row4_col7, #T_760fd_row5_col7, #T_760fd_row6_col7, #T_760fd_row7_col7, #T_760fd_row8_col7, #T_760fd_row9_col7, #T_760fd_row10_col7, #T_760fd_row11_col7, #T_760fd_row12_col7, #T_760fd_row13_col7, #T_760fd_row14_col7, #T_760fd_row15_col7, #T_760fd_row16_col7, #T_760fd_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_760fd_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_760fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_760fd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_760fd_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_760fd_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_760fd_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_760fd_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_760fd_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_760fd_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_760fd_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_760fd_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_760fd_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_760fd_row0_col1" class="data row0 col1" >1.0244</td>
#       <td id="T_760fd_row0_col2" class="data row0 col2" >2.3413</td>
#       <td id="T_760fd_row0_col3" class="data row0 col3" >1.5256</td>
#       <td id="T_760fd_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_760fd_row0_col5" class="data row0 col5" >0.0010</td>
#       <td id="T_760fd_row0_col6" class="data row0 col6" >0.0006</td>
#       <td id="T_760fd_row0_col7" class="data row0 col7" >9.8160</td>
#     </tr>
#     <tr>
#       <th id="T_760fd_level0_row1" class="row_heading level0 row1" >omp</th>
#       <td id="T_760fd_row1_col0" class="data row1 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_760fd_row1_col1" class="data row1 col1" >1.0178</td>
#       <td id="T_760fd_row1_col2" class="data row1 col2" >2.3885</td>
#       <td id="T_760fd_row1_col3" class="data row1 col3" >1.5394</td>
#       <td id="T_760fd_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_760fd_row1_col5" class="data row1 col5" >0.0010</td>
#       <td id="T_760fd_row1_col6" class="data row1 col6" >0.0006</td>
#       <td id="T_760fd_row1_col7" class="data row1 col7" >5.9280</td>
#     </tr>
#     <tr>
#       <th id="T_760fd_level0_row2" class="row_heading level0 row2" >lasso</th>
#       <td id="T_760fd_row2_col0" class="data row2 col0" >Lasso Regression</td>
#       <td id="T_760fd_row2_col1" class="data row2 col1" >1.0288</td>
#       <td id="T_760fd_row2_col2" class="data row2 col2" >2.4406</td>
#       <td id="T_760fd_row2_col3" class="data row2 col3" >1.5554</td>
#       <td id="T_760fd_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_760fd_row2_col5" class="data row2 col5" >0.0010</td>
#       <td id="T_760fd_row2_col6" class="data row2 col6" >0.0006</td>
#       <td id="T_760fd_row2_col7" class="data row2 col7" >5.6040</td>
#     </tr>
#     <tr>
#       <th id="T_760fd_level0_row3" class="row_heading level0 row3" >par</th>
#       <td id="T_760fd_row3_col0" class="data row3 col0" >Passive Aggressive Regressor</td>
#       <td id="T_760fd_row3_col1" class="data row3 col1" >2.1950</td>
#       <td id="T_760fd_row3_col2" class="data row3 col2" >13.4988</td>
#       <td id="T_760fd_row3_col3" class="data row3 col3" >3.1704</td>
#       <td id="T_760fd_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_760fd_row3_col5" class="data row3 col5" >0.0016</td>
#       <td id="T_760fd_row3_col6" class="data row3 col6" >0.0012</td>
#       <td id="T_760fd_row3_col7" class="data row3 col7" >5.7930</td>
#     </tr>
#     <tr>
#       <th id="T_760fd_level0_row4" class="row_heading level0 row4" >br</th>
#       <td id="T_760fd_row4_col0" class="data row4 col0" >Bayesian Ridge</td>
#       <td id="T_760fd_row4_col1" class="data row4 col1" >1.0185</td>
#       <td id="T_760fd_row4_col2" class="data row4 col2" >2.3374</td>
#       <td id="T_760fd_row4_col3" class="data row4 col3" >1.5241</td>
#       <td id="T_760fd_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_760fd_row4_col5" class="data row4 col5" >0.0010</td>
#       <td id="T_760fd_row4_col6" class="data row4 col6" >0.0006</td>
#       <td id="T_760fd_row4_col7" class="data row4 col7" >5.8830</td>
#     </tr>
#     <tr>
#       <th id="T_760fd_level0_row5" class="row_heading level0 row5" >huber</th>
#       <td id="T_760fd_row5_col0" class="data row5 col0" >Huber Regressor</td>
#       <td id="T_760fd_row5_col1" class="data row5 col1" >1.0064</td>
#       <td id="T_760fd_row5_col2" class="data row5 col2" >2.3473</td>
#       <td id="T_760fd_row5_col3" class="data row5 col3" >1.5270</td>
#       <td id="T_760fd_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_760fd_row5_col5" class="data row5 col5" >0.0010</td>
#       <td id="T_760fd_row5_col6" class="data row5 col6" >0.0006</td>
#       <td id="T_760fd_row5_col7" class="data row5 col7" >5.8670</td>
#     </tr>
#     <tr>
#       <th id="T_760fd_level0_row6" class="row_heading l

# %%
#Vemos que el que mejor nos viene es regresión lineal
lr = create_model('lr') # lo creamos
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             09:25:59
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .    Compiling Library
# <style type="text/css">
# #T_fb1ea_row10_col0, #T_fb1ea_row10_col1, #T_fb1ea_row10_col2, #T_fb1ea_row10_col3, #T_fb1ea_row10_col4, #T_fb1ea_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_fb1ea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb1ea_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_fb1ea_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_fb1ea_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_fb1ea_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_fb1ea_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_fb1ea_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb1ea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fb1ea_row0_col0" class="data row0 col0" >0.5871</td>
#       <td id="T_fb1ea_row0_col1" class="data row0 col1" >0.9209</td>
#       <td id="T_fb1ea_row0_col2" class="data row0 col2" >0.9596</td>
#       <td id="T_fb1ea_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_fb1ea_row0_col4" class="data row0 col4" >0.0005</td>
#       <td id="T_fb1ea_row0_col5" class="data row0 col5" >0.0003</td>
#     </tr>
#     <tr>
#       <th id="T_fb1ea_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fb1ea_row1_col0" class="data row1 col0" >0.6480</td>
#       <td id="T_fb1ea_row1_col1" class="data row1 col1" >1.1502</td>
#       <td id="T_fb1ea_row1_col2" class="data row1 col2" >1.0725</td>
#       <td id="T_fb1ea_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_fb1ea_row1_col4" class="data row1 col4" >0.0006</td>
#       <td id="T_fb1ea_row1_col5" class="data row1 col5" >0.0003</td>
#     </tr>
#     <tr>
#       <th id="T_fb1ea_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fb1ea_row2_col0" class="data row2 col0" >0.8362</td>
#       <td id="T_fb1ea_row2_col1" class="data row2 col1" >1.5934</td>
#       <td id="T_fb1ea_row2_col2" class="data row2 col2" >1.2623</td>
#       <td id="T_fb1ea_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_fb1ea_row2_col4" class="data row2 col4" >0.0009</td>
#       <td id="T_fb1ea_row2_col5" class="data row2 col5" >0.0006</td>
#     </tr>
#     <tr>
#       <th id="T_fb1ea_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fb1ea_row3_col0" class="data row3 col0" >0.7692</td>
#       <td id="T_fb1ea_row3_col1" class="data row3 col1" >1.6341</td>
#       <td id="T_fb1ea_row3_col2" class="data row3 col2" >1.2783</td>
#       <td id="T_fb1ea_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_fb1ea_row3_col4" class="data row3 col4" >0.0008</td>
#       <td id="T_fb1ea_row3_col5" class="data row3 col5" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_fb1ea_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fb1ea_row4_col0" class="data row4 col0" >0.8006</td>
#       <td id="T_fb1ea_row4_col1" class="data row4 col1" >1.5518</td>
#       <td id="T_fb1ea_row4_col2" class="data row4 col2" >1.2457</td>
#       <td id="T_fb1ea_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_fb1ea_row4_col4" class="data row4 col4" >0.0007</td>
#       <td id="T_fb1ea_row4_col5" class="data row4 col5" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_fb1ea_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fb1ea_row5_col0" class="data row5 col0" >0.7269</td>
#       <td id="T_fb1ea_row5_col1" class="data row5 col1" >1.3220</td>
#       <td id="T_fb1ea_row5_col2" class="data row5 col2" >1.1498</td>
#       <td id="T_fb1ea_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_fb1ea_row5_col4" class="data row5 col4" >0.0007</td>
#       <td id="T_fb1ea_row5_col5" class="data row5 col5" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_fb1ea_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fb1ea_row6_col0" class="data row6 col0" >0.7161</td>
#       <td id="T_fb1ea_row6_col1" class="data row6 col1" >1.3602</td>
#       <td id="T_fb1ea_row6_col2" class="data row6 col2" >1.1663</td>
#       <td id="T_fb1ea_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_fb1ea_row6_col4" class="data row6 col4" >0.0008</td>
#       <td id="T_fb1ea_row6_col5" class="data row6 col5" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_fb1ea_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fb1ea_row7_col0" class="data row7 col0" >0.9215</td>
#       <td id="T_fb1ea_row7_col1" class="data row7 col1" >1.9929</td>
#       <td id="T_fb1ea_row7_col2" class="data row7 col2" >1.4117</td>
#       <td id="T_fb1ea_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_fb1ea_row7_col4" class="data row7 col4" >0.0010</td>
#       <td id="T_fb1ea_row7_col5" class="data row7 col5" >0.0006</td>
#     </tr>
#     <tr>
#       <th id="T_fb1ea_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fb1ea_row8_col0" class="data row8 col0" >0.6311</td>
#       <td id="T_fb1ea_row8_col1" class="data row8 col1" >1.0891</td>
#       <td id="T_fb1ea_row8_col2" class="data row8 col2" >1.0436</td>
#       <td id="T_fb1ea_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_fb1ea_row8_col4" class="data row8 col4" >0.0007</td>
#       <td id="T_fb1ea_row8_col5" class="data row8 col5" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_fb1ea_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fb1ea_row9_col0" class="data row9 col0" >0.6995</td>
#       <td id="T_fb1ea_row9_col1" class="data row9 col1" >1.3260</td>
#       <td id="T_fb1ea_row9_col2" class="data row9 col2" >1.1515</td>
#       <td id="T_fb1ea_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_fb1ea_row9_col4" class="data row9 col4" >0.0008</td>
#       <td id="T_fb1ea_row9_col5" class="data row9 col5" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_fb1ea_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_fb1ea_row10_col0" class="data row10 col0" >0.7336</td>
#       <td id="T_fb1ea_row10_col1" class="data row10 col1" >1.3941</td>
#       <td id="T_fb1ea_row10_col2" class="data row10 col2" >1.1741</td>
#       <td id="T_fb1ea_row10_col3" class="data row10 col3" >1.0000</td>
#       <td id="T_fb1ea_row10_col4" class="data row10 col4" >0.0008</td>
#       <td id="T_fb1ea_row10_col5" class="data row10 col5" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_fb1ea_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_fb1ea_row11_col0" class="data row11 col0" >0.0961</td>
#       <td id="T_fb1ea_row11_col1" class="data row11 col1" >0.2947</td>
#       <td id="T_fb1ea_row11_col2" class="data row11 col2" >0.1244</td>
#       <td id="T_fb1ea_row11_col3" class="data row11 col3" >0.0000</td>
#       <td id="T_fb1ea_row11_col4" class="data row11 col4" >0.0001</td>
#       <td id="T_fb1ea_row11_col5" class="data row11 col5" >0.0001</td>
#     </tr>
#   </tbody>
# </table>

# %%
# lo tuneamos XD
tuned_lr = tune_model(lr)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   09:29:18
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .          Linear Regression
# <style type="text/css">
# #T_d06d5_row10_col0, #T_d06d5_row10_col1, #T_d06d5_row10_col2, #T_d06d5_row10_col3, #T_d06d5_row10_col4, #T_d06d5_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d06d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d06d5_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d06d5_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d06d5_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d06d5_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d06d5_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d06d5_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d06d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d06d5_row0_col0" class="data row0 col0" >0.5860</td>
#       <td id="T_d06d5_row0_col1" class="data row0 col1" >0.9173</td>
#       <td id="T_d06d5_row0_col2" class="data row0 col2" >0.9577</td>
#       <td id="T_d06d5_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_d06d5_row0_col4" class="data row0 col4" >0.0005</td>
#       <td id="T_d06d5_row0_col5" class="data row0 col5" >0.0003</td>
#     </tr>
#     <tr>
#       <th id="T_d06d5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d06d5_row1_col0" class="data row1 col0" >0.6480</td>
#       <td id="T_d06d5_row1_col1" class="data row1 col1" >1.1502</td>
#       <td id="T_d06d5_row1_col2" class="data row1 col2" >1.0725</td>
#       <td id="T_d06d5_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_d06d5_row1_col4" class="data row1 col4" >0.0006</td>
#       <td id="T_d06d5_row1_col5" class="data row1 col5" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_d06d5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d06d5_row2_col0" class="data row2 col0" >0.8364</td>
#       <td id="T_d06d5_row2_col1" class="data row2 col1" >1.5940</td>
#       <td id="T_d06d5_row2_col2" class="data row2 col2" >1.2625</td>
#       <td id="T_d06d5_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_d06d5_row2_col4" class="data row2 col4" >0.0009</td>
#       <td id="T_d06d5_row2_col5" class="data row2 col5" >0.0006</td>
#     </tr>
#     <tr>
#       <th id="T_d06d5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d06d5_row3_col0" class="data row3 col0" >0.7692</td>
#       <td id="T_d06d5_row3_col1" class="data row3 col1" >1.6341</td>
#       <td id="T_d06d5_row3_col2" class="data row3 col2" >1.2783</td>
#       <td id="T_d06d5_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_d06d5_row3_col4" class="data row3 col4" >0.0008</td>
#       <td id="T_d06d5_row3_col5" class="data row3 col5" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_d06d5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d06d5_row4_col0" class="data row4 col0" >0.8006</td>
#       <td id="T_d06d5_row4_col1" class="data row4 col1" >1.5518</td>
#       <td id="T_d06d5_row4_col2" class="data row4 col2" >1.2457</td>
#       <td id="T_d06d5_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_d06d5_row4_col4" class="data row4 col4" >0.0007</td>
#       <td id="T_d06d5_row4_col5" class="data row4 col5" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_d06d5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d06d5_row5_col0" class="data row5 col0" >0.7268</td>
#       <td id="T_d06d5_row5_col1" class="data row5 col1" >1.3217</td>
#       <td id="T_d06d5_row5_col2" class="data row5 col2" >1.1496</td>
#       <td id="T_d06d5_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_d06d5_row5_col4" class="data row5 col4" >0.0007</td>
#       <td id="T_d06d5_row5_col5" class="data row5 col5" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_d06d5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d06d5_row6_col0" class="data row6 col0" >0.7162</td>
#       <td id="T_d06d5_row6_col1" class="data row6 col1" >1.3599</td>
#       <td id="T_d06d5_row6_col2" class="data row6 col2" >1.1662</td>
#       <td id="T_d06d5_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_d06d5_row6_col4" class="data row6 col4" >0.0008</td>
#       <td id="T_d06d5_row6_col5" class="data row6 col5" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_d06d5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d06d5_row7_col0" class="data row7 col0" >0.9217</td>
#       <td id="T_d06d5_row7_col1" class="data row7 col1" >1.9931</td>
#       <td id="T_d06d5_row7_col2" class="data row7 col2" >1.4118</td>
#       <td id="T_d06d5_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_d06d5_row7_col4" class="data row7 col4" >0.0010</td>
#       <td id="T_d06d5_row7_col5" class="data row7 col5" >0.0006</td>
#     </tr>
#     <tr>
#       <th id="T_d06d5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d06d5_row8_col0" class="data row8 col0" >0.6311</td>
#       <td id="T_d06d5_row8_col1" class="data row8 col1" >1.0891</td>
#       <td id="T_d06d5_row8_col2" class="data row8 col2" >1.0436</td>
#       <td id="T_d06d5_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_d06d5_row8_col4" class="data row8 col4" >0.0007</td>
#       <td id="T_d06d5_row8_col5" class="data row8 col5" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_d06d5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d06d5_row9_col0" class="data row9 col0" >0.6993</td>
#       <td id="T_d06d5_row9_col1" class="data row9 col1" >1.3254</td>
#       <td id="T_d06d5_row9_col2" class="data row9 col2" >1.1513</td>
#       <td id="T_d06d5_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_d06d5_row9_col4" class="data row9 col4" >0.0008</td>
#       <td id="T_d06d5_row9_col5" class="data row9 col5" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_d06d5_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_d06d5_row10_col0" class="data row10 col0" >0.7335</td>
#       <td id="T_d06d5_row10_col1" class="data row10 col1" >1.3936</td>
#       <td id="T_d06d5_row10_col2" class="data row10 col2" >1.1739</td>
#       <td id="T_d06d5_row10_col3" class="data row10 col3" >1.0000</td>
#       <td id="T_d06d5_row10_col4" class="data row10 col4" >0.0008</td>
#       <td id="T_d06d5_row10_col5" class="data row10 col5" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_d06d5_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_d06d5_row11_col0" class="data row11 col0" >0.0964</td>
#       <td id="T_d06d5_row11_col1" class="data row11 col1" >0.2953</td>
#       <td id="T_d06d5_row11_col2" class="data row11 col2" >0.1248</td>
#       <td id="T_d06d5_row11_col3" class="data row11 col3" >0.0000</td>
#       <td id="T_d06d5_row11_col4" class="data row11 col4" >0.0001</td>
#       <td id="T_d06d5_row11_col5" class="data row11 col5" >0.0001</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 2 candidates, totalling 20 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
#Veamos como se comporta
evaluate_model(tuned_lr)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
#finalizamos el modelo
final_lr_best = finalize_model(tuned_lr)

# %%
#guardamos el modelo 
save_model( final_lr_best, 'ml_unicornios')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\fabia\AppData\Local\Temp\joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Year_Founded', 'Funding',
#                                               'Years_Since_Founded',
#                                               'Funding_Age_Ratio', 'ROI'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['Industry', 'Country',
#                                               'Continent'],
#                                      transformer=SimpleImputer(s...
#                                      transformer=OneHotEncoder(cols=['Industry',
#                                                                      'Continent'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('rest_encoding',
#                   TransformerWrapper(include=['Country'],
#                                      transformer=TargetEncoder(cols=['Country'],
#                                                                handle_missing='return_nan'))),
#                  ('remove_outliers',
#                   TransformerWrapper(transformer=RemoveOutliers(random_state=4195))),
#                  ('actual_estimator', LinearRegression(n_jobs=-1))]),
#  'ml_unicornios.pkl')

# %%
df.columns
# Out:
# Index(['Industry', 'Country', 'Year_Founded', 'Funding', 'Continent',
#        'Valuation'],
#       dtype='object')

# %%
print(df['Continent'].unique())
# Out:
# ['Asia' 'North America' 'Europe' 'Oceania' 'South America' 'Africa']
